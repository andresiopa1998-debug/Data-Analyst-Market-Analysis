# %%
import pandas as pd
df = pd.read_csv('/content/AI Job Market Dataset-Andre - AI Job Market Dataset.csv.csv')

# Look at ALL entry-level roles paying > $80k from 2020-2026
top_entry = df[(df['experience_level'] == 'Entry') & (df['salary'] > 80000)]

skill_cols = ['skills_python', 'skills_sql', 'skills_ml', 'skills_deep_learning', 'skills_cloud']
print(top_entry[skill_cols].sum())
# Out:
# skills_python            984
# skills_sql              1042
# skills_ml               1239
# skills_deep_learning    1210
# skills_cloud            1120
# dtype: int64
